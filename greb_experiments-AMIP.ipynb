# %% [markdown]
# ## Experiments with the GREB Model

# %% [markdown]
# Initial experiments
# - Wind anomaly:
#     - v_anom.pos/neg
#     - u_anom.pos/neg
#     - u_vanom.pos/neg
# - Cloud anomaly:
#     - cld.inc
#     - cld.dec
# - Soil Moisture anomaly:
#     - smc.wet
#     - smc.dry
# - SST anomaly

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import iris
import iris.quickplot as qplt
import iris.plot as iplt
import matplotlib.pyplot as plt
import mycmaps as mc
import greb_tools as gt
# %matplotlib inline

# %% [markdown]
# ### Creat input files and run model

# %% [markdown]
# Define the experiment name

# %%
# exp = "cld.pos"
# exp = "smc.neg"
# exp = "smc.pos"
# exp = "clim"
# exp = "u_anom.pos"
# exp = "uv_anom.pos"
exp = "v_anom.pos"
# exp = "icealb"
print exp
# Out:
# v_anom.pos

# %% [markdown]
# ### Create the input files.

# %%
import write_input as wi
print exp
if exp == "v_anom.pos":
    wi.write_v_anom("pos")
if exp == "uv_anom.pos":
    wi.write_v_anom("pos")
    wi.write_u_anom("pos")   
if exp == "u_anom.pos":
    wi.write_u_anom("pos")
if exp == "cld.pos":
    wi.write_cld("pos")
if exp == "cld.neg":
    wi.write_cld("neg")
if exp == "smc.pos":
    wi.write_smc("pos")
if exp == "smc.neg":
    wi.write_smc("neg")
if exp == "clim":
    print "nothing needs doin'"
# Out:
# smc.pos
# Soil moisture loaded
# Positive anomaly
# Writing soil.moisture.smc.anom/nc

# %% [markdown]
# ### Copy the binary input files to the main directory

# %%
import shutil as sh
import glob
import os
import re

main_dir = '/home/nicholat/project/greb/'
input_dir = main_dir + 'input_files/'
orig_input_dir = main_dir + 'orig_input/'

# copy the original input files into the main folder
for filename in glob.glob(os.path.join(orig_input_dir, '*')):
    sh.copy(filename, main_dir)
print "Original input files copied to main dir"
print "Anom placeholder bin files copied to main dir"

if exp == 'v_anom.pos':
    sh.copyfile(input_dir+'meridional.wind.anom',
                main_dir+'meridional.wind.anom')
    print "Anomalous meridional wind input copied to main dir"
    
if exp == 'u_anom.pos':
    sh.copyfile(input_dir+'zonal.wind.anom',
                main_dir+'zonal.wind.anom')
    print "Anomalous zonal wind input copied to main dir"
    
if exp == 'uv_anom.pos':
    sh.copyfile(input_dir+'zonal.wind.anom',
                main_dir+'zonal.wind.anom')
    print "Anomalous zonal wind input copied to main dir"
    sh.copyfile(input_dir+'meridional.wind.anom',
                main_dir+'meridional.wind.anom')
    print "Anomalous meridional wind input copied to main dir"

if exp == 'cld.pos':
    sh.copyfile(input_dir+'cloud.cover.cld.anom',
                main_dir+'cloud.cover.anom')
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','cld',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)

    print "Anomalous cloud clover input copied to main dir"
    
if exp == 'smc.pos':
    sh.copyfile(input_dir+'soil.moisture.smc.anom',
                main_dir+'soil.moisture.anom')
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','smc',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)

    print "Anomalous soil moisture input copied to main dir"

if exp == 'smc.neg':
    sh.copyfile(input_dir+'soil.moisture.smc.anom',
                main_dir+'soil.moisture.anom')
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','smc',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)

    print "Anomalous soil moisture input copied to main dir"
# Out:
# Original input files copied to main dir
# Anom placeholder bin files copied to main dir
# anom = 'smc' ! character(len3) choose anomaly (smc (wind), smc, cld)
# Anomalous soil moisture input copied to main dir

# %% [markdown]
# ### Check Input

# %%
anom_list = gt.read_anom_bin()
fig = plt.figure(figsize=(5,5))
plt.subplot(3,2,1)
iplt.pcolormesh(anom_list[0][:,:,-1],cmap='bwr')
plt.title(anom_list[0].long_name)
plt.gca().coastlines()
plt.subplot(3,2,2)
iplt.pcolormesh(anom_list[1][:,:,-1],cmap='bwr')
plt.title(anom_list[1].long_name)
plt.gca().coastlines()
plt.subplot(3,2,3)
iplt.pcolormesh(anom_list[2][:,:,-1],cmap='bwr')
plt.title(anom_list[2].long_name)
plt.gca().coastlines()
plt.subplot(3,2,4)
iplt.pcolormesh(anom_list[3][:,:,-1],cmap='bwr')
plt.title(anom_list[3].long_name)
plt.gca().coastlines()

# %% [markdown]
# ### Run the model

# %%
print anom_list[2].data.max()
qplt.pcmeshclf(anom_list[2][:,:,0])
# Out:
# 0.0813679918647

# %%
# %%bash
# cat namelist
# Out:
# &NUMERICS
# time_flux = 3  ! length of flux corrections run [yrs]
# time_ctrl = 5  ! length of control run [yrs
# time_scnr = 50  ! length of scenariorun [yrs
# /
# &PHYSICS
# log_exp = 10 ! complete GREB model; 2xCO2 forcing
# anom = 'smc' ! character(len3) choose anomaly (smc (wind), smc, cld)
# /

# %% [markdown]
# ### Run GREB model

# %%
# %%bash
# ./compile_run_greb.sh
# Out:
#  % start climate shell
#  % diagonstic point lat/lon:    30.0000000       172.500000
#  % time flux/control/scenario:            3           5          50
#  % flux correction    340.000000
#    0.00000000       4.77062988       26.7869568       4.84933472
#    0.00000000       4.77062988       26.7869568       4.84933472
#    0.00000000       4.77062988       26.7869568       4.84933472
#  % CONTROL RUN CO2=   340.000000       time=           5 yr
#    1970.00000       4.77069092       26.7869873       4.84936523
#    1970.00000       4.77069092       26.7869873       4.84936523
#    1970.00000       4.77069092       26.7869873       4.84936523
#    1970.00000       4.77075195       26.7870178       4.84936523
#    1970.00000       4.77069092       26.7870483       4.84939575
#  % SCENARIO EXP:           10   time=          50 yr
#  anom = smc
#    1940.00000       4.77191162       26.7868652       4.82638550
#    1941.00000       4.76702881       26.7859497       4.82315063
#    1942.00000       4.76461792       26.7846985       4.82196045
#    1943.00000       4.76266479       26.7836304       4.82101440
#    1944.00000       4.76089478       26.7825928       4.82025146
#    1945.00000       4.75939941       26.7816772       4.81930542
#    1946.00000       4.75799561       26.7807312       4.81863403
#    1947.00000       4.75671387       26.7797241       4.81787109
#    1948.00000       4.75549316       26.7787476       4.81716919
#    1949.00000       4.75439453       26.7780151       4.81652832
#    1950.00000       4.75341797       26.7772217       4.81591797
#    1951.00000       4.75241089       26.7764587       4.81536865
#    1952.00000       4.75155640       26.7757263       4.81488037
#    1953.00000       4.75079346       26.7749329       4.81436157
#    1954.00000       4.75000000       26.7744446       4.81393433
#    1955.00000       4.74932861       26.7738953       4.81362915
#    1956.00000       4.74862671       26.7733765       4.81326294
#    1957.00000       4.74798584       26.7729492       4.81301880
#    1958.00000       4.74746704       26.7725220       4.81271362
#    1959.00000       4.74688721       26.7720642       4.81240845
#    1960.00000       4.74639893       26.7716980       4.81210327
#    1961.00000       4.74594116       26.7713318       4.81185913
#    1962.00000       4.74551392       26.7709961       4.81164551
#    1963.00000       4.74514771       26.7707520       4.81146240
#    1964.00000       4.74472046       26.7704468       4.81127930
#    1965.00000       4.74435425       26.7702332       4.81106567
#    1966.00000       4.74401855       26.7700500       4.81094360
#    1967.00000       4.74371338       26.7698059       4.81076050
#    1968.00000       4.74334717       26.7695618       4.81063843
#    1969.00000       4.74313354       26.7692871       4.81057739
#    1970.00000       4.74282837       26.7690735       4.81045532
#    1971.00000       4.74255371       26.7689209       4.81039429
#    1972.00000       4.74237061       26.7687988       4.81027222
#    1973.00000       4.74218750       26.7686462       4.81015015
#    1974.00000       4.74191284       26.7685852       4.80999756
#    1975.00000       4.74176025       26.7683716       4.80993652
#    1976.00000       4.74151611       26.7681580       4.80984497
#    1977.00000       4.74139404       26.7680054       4.80975342
#    1978.00000       4.74118042       26.7679138       4.80972290
#    1979.00000       4.74102783       26.7677917       4.80963135
#    1980.00000       4.74087524       26.7676697       4.80957031
#    1981.00000       4.74075317       26.7675781       4.80953979
#    1982.00000       4.74060059       26.7674866       4.80947876
#    1983.00000       4.74047852       26.7674255       4.80941772
#    1984.00000       4.74032593       26.7673035       4.80941772
#    1985.00000       4.74023438       26.7672424       4.80938721
#    1986.00000       4.74014282       26.7672119       4.80935669
#    1987.00000       4.74005127       26.7671509       4.80932617
#    1988.00000       4.73995972       26.7671509       4.80926514
#    1989.00000       4.73983765       26.7671204       4.80917358

# %% [markdown]
# ### Copy output to bin_dir and rename

# %%
# Copy the output files to bin_files dir and rename
bin_dir = main_dir + 'bin_files/'
sh.copyfile(main_dir + 'control',bin_dir + 'control.' + exp + '.bin')
sh.copyfile(main_dir + 'scenario',bin_dir + 'scenario.' + exp + '.bin')

# %%
ls bin_files/
# Out:
# control.all.pos.4ycomp.bin      scenario.all.pos.4ycomp.bin
# control.cld.pos.4ycomp.bin      scenario.cld.pos.4ycomp.bin
# control.cld.pos.bin             scenario.cld.pos.bin
# control.clim.bin                scenario.clim.bin
# control.icealb.bin              scenario.icealb.bin
# control.smc.dry.bin             scenario.smc.dry.bin
# control.smc.neg.bin             scenario.smc.neg.bin
# control.smc.pos.4ycomp.bin      scenario.smc.pos.4ycomp.bin
# control.smc.pos.bin             scenario.smc.pos.bin
# control.test.bin                scenario.test.bin
# control.u_anom.pos.4ycomp.bin   scenario.u_anom.pos.4ycomp.bin
# control.u_anom.pos.bin          scenario.u_anom.pos.bin
# control.uv_anom.pos.4ycomp.bin  scenario.uv_anom.pos.4ycomp.bin
# control.uv_anom.pos.bin         scenario.uv_anom.pos.bin
# control.v_anom.pos.4ycomp.bin   scenario.vanom.bin
# control.v_anom.pos.bin          scenario.v_anom.pos.4ycomp.bin
# control.vwind_1msanom.bin       scenario.v_anom.pos.bin
# scenario.4ycomp.cld.pos.bin     scenario.vwind_1msanom.bin

# %% [markdown]
# ### Convert output binary files to netcdf

# %%
import output_to_nc as b2n

cube_list = b2n.write_exp(exp)
# Out:
# ./bin_files/scenario.smc.pos.bin
# tdim = 600
# Save cube as ./ncfiles/t_surf.smc.pos.nc
# tdim = 600
# Save cube as ./ncfiles/t_atmos.smc.pos.nc
# tdim = 600
# Save cube as ./ncfiles/t_ocean.smc.pos.nc
# tdim = 600
# Save cube as ./ncfiles/vapour.smc.pos.nc
# tdim = 600
# Save cube as ./ncfiles/albedo.smc.pos.nc

# %% [markdown]
# ### Check Output

# %%
# exp = "cld.pos"
# exp = "smc.neg"
exp = "smc.pos"
# exp = "clim"
# exp = "u_anom.pos"
# exp = "uv_anom.pos"
# exp = "v_anom.pos"
# exp = "icealb"
print exp
# Out:
# smc.pos

# %%
nc_dir = main_dir+'ncfiles/'
t_surf_clim = iris.load_cube(nc_dir + '/t_surf.clim.nc')
t_surf = iris.load_cube(nc_dir + '/t_surf.' + exp + '.nc')

gt.try_cube(t_surf_clim)
gt.try_cube(t_surf)

# take the mean of last year 
t_surf_clim_mean = t_surf_clim[:,:,-13:-1].collapsed('time',iris.analysis.MEAN)
t_surf_mean = t_surf[:,:,-13:-1].collapsed('time',iris.analysis.MEAN)
dif = t_surf_mean - t_surf_clim_mean
dif.long_name = 'Tsfc difference '+exp
qplt.pcmeshclf(dif,vmin=-1.0,vmax=1.0)
plt.savefig('./figures/tsfc_dif.'+exp+'.pdf')
#fig = plt.figure(figsize=(12,8))
#plt.subplot(2,2,1)
#qplt.pcmeshclf(t_surf_clim_mean,hold=True,cmap=mc.jetwhite(),vmax = (273.15+30), vmin = (273.15-30))
#plt.subplot(2,2,2)
#qplt.pcmeshclf(t_surf_mean,hold=True,cmap=mc.jetwhite(),vmax = (273.15+30), vmin = (273.15-30))

# %%
# %whos
# Out:
# Variable           Type        Data/Info
# ----------------------------------------
# anom_list          CubeList    0: cloud.cover.anom / (1)<...>longitude: 96; time: 730)
# b2n                module      <module 'output_to_nc' from 'output_to_nc.pyc'>
# bin_dir            str         /home/nicholat/project/greb/bin_files/
# cube_list          CubeList    0: surface_temperature / <...>longitude: 96; time: 600)
# dif                Cube        unknown / (K)            <...>         -              x
# exp                str         smc.neg
# f_in               file        <closed file 'namelist', <...>de 'r' at 0x7f56c174d300>
# f_out              file        <closed file 'namelist', <...>de 'w' at 0x7f56c174da50>
# fig                Figure      Figure(400x400)
# filename           str         /home/nicholat/project/gr<...>nput/meridional.wind.anom
# glob               module      <module 'glob' from '/usr<...>/lib/python2.7/glob.pyc'>
# gt                 module      <module 'greb_tools' from 'greb_tools.pyc'>
# input_dir          str         /home/nicholat/project/greb/input_files/
# iplt               module      <module 'iris.plot' from <...>-packages/iris/plot.pyc'>
# iris               module      <module 'iris' from '/usr<...>kages/iris/__init__.pyc'>
# lines              list        n=9
# main_dir           str         /home/nicholat/project/greb/
# mc                 module      <module 'mycmaps' from '/<...>lat/climate/mycmaps.pyc'>
# nc_dir             str         /home/nicholat/project/greb/ncfiles/
# np                 module      <module 'numpy' from '/us<...>ages/numpy/__init__.pyc'>
# orig_input_dir     str         /home/nicholat/project/greb/orig_input/
# os                 module      <module 'os' from '/usr/lib/python2.7/os.pyc'>
# plt                module      <module 'matplotlib.pyplo<...>s/matplotlib/pyplot.pyc'>
# qplt               module      <module 'iris.quickplot' <...>kages/iris/quickplot.py'>
# re                 module      <module 're' from '/usr/lib/python2.7/re.pyc'>
# sh                 module      <module 'shutil' from '/u<...>ib/python2.7/shutil.pyc'>
# t_surf             Cube        surface_temperature / (K)<...>rce: Data from GREB model
# t_surf_clim        Cube        surface_temperature / (K)<...>rce: Data from GREB model
# t_surf_clim_mean   Cube        surface_temperature / (K)<...>ds:\n          mean: time
# t_surf_mean        Cube        surface_temperature / (K)<...>ds:\n          mean: time
# wi                 module      <module 'write_input' from 'write_input.py'>
