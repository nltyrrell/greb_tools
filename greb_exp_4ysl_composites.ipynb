# %% [markdown]
# ## Experiments with the GREB Model

# %% [markdown]
# These experiments use anomaly data from the 4year oscillation run
#
# Initial experiments
# - Wind anomaly:
#     - v_anom.pos/neg
#     - u_anom.pos/neg
#     - u_vanom.pos/neg
# - Cloud anomaly:
#     - cld.inc
#     - cld.dec
# - Soil Moisture anomaly:
#     - smc.wet
#     - smc.dry
# - SST anomaly

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import iris
import iris.quickplot as qplt
import iris.plot as iplt
import matplotlib.pyplot as plt
import mycmaps as mc
import greb_tools as gt
# %matplotlib inline

# %% [markdown]
# ### Creat input files and run model

# %% [markdown]
# Define the experiment name

# %%
#exp = "cld.pos.4ycomp"
# exp = "smc.neg"    trop = iris.Constraint(air_pressure = lambda p: plev_top <= p <= plev_bottom)
# exp = "smc.pos.4ycomp"
# exp = "clim"
# exp = "u_anom.pos.4ycomp"
exp = "sst_anom.pos.4ycomp"
# exp = "uv_anom.pos.4ycomp"
# exp = "v_anom.pos.4ycomp"
# exp = "icealb"
# exp = "all.pos.4ycomp"
print exp
# Out:
# sst_anom.pos.4ycomp

# %% [markdown]
# ### Create the input files.

# %%
import write_input as wi
print exp
if exp == "sst_anom.pos.4ycomp":
    wi.write_sst_4ycomp("pos")
if exp == "v_anom.pos.4ycomp":
    wi.write_v_4ycomp("pos")
if exp == "uv_anom.pos.4ycomp":
    wi.write_v_4ycomp("pos")
    wi.write_u_4ycomp("pos")   
if exp == "u_anom.pos.4ycomp":
    wi.write_u_4ycomp("pos")
if exp == "cld.pos.4ycomp":
    wi.write_cld_4ycomp("pos")
if exp == "cld.neg.4ycomp":
    wi.write_cld_4ycomp("neg")
if exp == "smc.pos.4ycomp":
    wi.write_smc_4ycomp("pos")
if exp == "smc.neg.4ycomp":
    wi.write_smc_4ycomp("neg")
if exp == "clim":
    print "nothing needs doin'"
if exp == "all.pos.4ycomp":
    wi.write_v_4ycomp("pos")
    wi.write_u_4ycomp("pos")   
    wi.write_cld_4ycomp("pos")
    wi.write_smc_4ycomp("pos")
if exp == "all_sst.pos.4ycomp":
    wi.write_v_4ycomp("pos")
    wi.write_u_4ycomp("pos")   
    wi.write_cld_4ycomp("pos")
    wi.write_smc_4ycomp("pos")
# Out:
# all.pos.4ycomp
# meridional.wind and anomalous wind loaded
# Positive anomaly
# Writing meridional.wind.4ycomp and meridional.wind.4ycomp.nc and anomalous wind loaded
# zonal.wind and anomalous wind loaded
# Positive anomaly
# Writing zonal.wind.anom and zonal.wind.anom.nc and anomalous wind loaded
# Cloud anom loaded
# Positive anomaly
# Writing cloud.cover.cld.anom/nc
# Soil moisture loaded
# Positive anomaly
# Writing soil.moisture.smc.anom/nc

# %% [markdown]
# ### Copy the binary input files to the main directory

# %%
import shutil as sh
import glob
import os
import re

main_dir = '/home/nicholat/project/greb/'
input_dir = main_dir + 'input_files/'
orig_input_dir = main_dir + 'orig_input/'

# copy the original input files into the main folder
for filename in glob.glob(os.path.join(orig_input_dir, '*')):
    sh.copy(filename, main_dir)
print "Original input files copied to main dir"
print "Anom placeholder bin files copied to main dir"

if exp == 'v_anom.pos.4ycomp':
    sh.copyfile(input_dir+'meridional.wind.4ycomp',
                main_dir+'meridional.wind.anom')
    print "Anomalous meridional wind input copied to main dir"
    
if exp == 'u_anom.pos.4ycomp':
    sh.copyfile(input_dir+'zonal.wind.4ycomp',
                main_dir+'zonal.wind.anom')
    print "Anomalous zonal wind input copied to main dir"
    
if exp == 'uv_anom.pos.4ycomp':
    sh.copyfile(input_dir+'zonal.wind.4ycomp',
                main_dir+'zonal.wind.anom')
    print "Anomalous zonal wind input copied to main dir"
    sh.copyfile(input_dir+'meridional.wind.4ycomp',
                main_dir+'meridional.wind.anom')
    print "Anomalous meridional wind input copied to main dir"

if exp == 'cld.pos.4ycomp':
    sh.copyfile(input_dir+'cloud.cover.cld.4ycomp',
                main_dir+'cloud.cover.anom')
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','cld',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)

    print "Anomalous cloud clover input copied to main dir"
    
if exp == 'smc.pos.4ycomp':
    sh.copyfile(input_dir+'soil.moisture.smc.4ycomp',
                main_dir+'soil.moisture.anom')
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','smc',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)

    print "Anomalous soil moisture input copied to main dir"

if exp == 'smc.neg.4ycomp':
    sh.copyfile(input_dir+'soil.moisture.smc.4ycomp',
                main_dir+'soil.moisture.anom')
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','smc',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)

    print "Anomalous soil moisture input copied to main dir"
    
if exp == 'all.pos.4ycomp':
    sh.copyfile(input_dir+'zonal.wind.4ycomp',
                main_dir+'zonal.wind.anom')
    print "Anomalous zonal wind input copied to main dir"
    sh.copyfile(input_dir+'meridional.wind.4ycomp',
                main_dir+'meridional.wind.anom')
    print "Anomalous meridional wind input copied to main dir"
    sh.copyfile(input_dir+'cloud.cover.cld.4ycomp',
                main_dir+'cloud.cover.anom')
    print "Anomalous cloud clover input copied to main dir"
    sh.copyfile(input_dir+'soil.moisture.smc.4ycomp',
                main_dir+'soil.moisture.anom')
    print "Anomalous soil moisture input copied to main dir"
    with open('namelist','r') as f_in:
        lines = f_in.readlines()
        # do the replacement in the ith line.
        lines[7] = re.sub('wnd','all',lines[7])
        print lines[7]
    with open('namelist','w') as f_out:
        f_out.writelines(lines)
    print "Namelist changed to 'all' experiment"
# Out:
# Original input files copied to main dir
# Anom placeholder bin files copied to main dir
# Anomalous zonal wind input copied to main dir
# Anomalous meridional wind input copied to main dir
# Anomalous cloud clover input copied to main dir
# Anomalous soil moisture input copied to main dir
# anom = 'all' ! character(len3) choose anomaly (all (wind), smc, cld)
#
# Namelist changed to 'all' experiment

# %% [markdown]
# ### Check Input

# %%
anom_list = gt.read_anom_bin()
fig = plt.figure(figsize=(5,5))
plt.subplot(3,2,1)
iplt.pcolormesh(anom_list[0][:,:,-1],cmap='bwr')
plt.title(anom_list[0].long_name)
plt.gca().coastlines()
plt.subplot(3,2,2)
iplt.pcolormesh(anom_list[1][:,:,-1],cmap='bwr')
plt.title(anom_list[1].long_name)
plt.gca().coastlines()
plt.subplot(3,2,3)
iplt.pcolormesh(anom_list[2][:,:,-1],cmap='bwr')
plt.title(anom_list[2].long_name)
plt.gca().coastlines()
plt.subplot(3,2,4)
iplt.pcolormesh(anom_list[3][:,:,-1],cmap='bwr')
plt.title(anom_list[3].long_name)
plt.gca().coastlines()

# %% [markdown]
# ### Run the model

# %%
# %%bash
# cat namelist
# Out:
# &NUMERICS
# time_flux = 3  ! length of flux corrections run [yrs]
# time_ctrl = 5  ! length of control run [yrs
# time_scnr = 50  ! length of scenariorun [yrs
# /
# &PHYSICS
# log_exp = 10 ! complete GREB model; 2xCO2 forcing
# anom = 'all' ! character(len3) choose anomaly (all (wind), smc, cld)
# /

# %% [markdown]
# ### Run GREB model

# %%
# %%bash
# ./compile_run_greb.sh
# Out:
#  % start climate shell
#  % diagonstic point lat/lon:    30.0000000       172.500000
#  % time flux/control/scenario:            3           5          50
#  % flux correction    340.000000
#    0.00000000       4.77062988       26.7869568       4.84933472
#    0.00000000       4.77062988       26.7869568       4.84933472
#    0.00000000       4.77062988       26.7869568       4.84933472
#  % CONTROL RUN CO2=   340.000000       time=           5 yr
#    1970.00000       4.77069092       26.7869873       4.84936523
#    1970.00000       4.77069092       26.7869873       4.84936523
#    1970.00000       4.77069092       26.7869873       4.84936523
#    1970.00000       4.77075195       26.7870178       4.84936523
#    1970.00000       4.77069092       26.7870483       4.84939575
#  % SCENARIO EXP:           10   time=          50 yr
#  anom = all
#  anom = wind
#  anom = smc
#  anom = cld
#    1940.00000       4.83312988       26.4952698       4.96023560
#    1941.00000       4.85357666       26.3532410       5.00860596
#    1942.00000       4.85845947       26.3179626       5.02172852
#    1943.00000       4.86187744       26.2919312       5.03030396
#    1944.00000       4.86431885       26.2721558       5.03723145
#    1945.00000       4.86605835       26.2576294       5.04318237
#    1946.00000       4.86737061       26.2463074       5.04861450
#    1947.00000       4.86816406       26.2380066       5.05276489
#    1948.00000       4.86886597       26.2315063       5.05618286
#    1949.00000       4.86929321       26.2267761       5.05969238
#    1950.00000       4.86965942       26.2234497       5.06243896
#    1951.00000       4.86981201       26.2206116       5.06466675
#    1952.00000       4.86990356       26.2185669       5.06677246
#    1953.00000       4.86993408       26.2166443       5.06842041
#    1954.00000       4.86993408       26.2154541       5.07003784
#    1955.00000       4.86996460       26.2145386       5.07141113
#    1956.00000       4.86993408       26.2140198       5.07260132
#    1957.00000       4.86993408       26.2133484       5.07369995
#    1958.00000       4.86987305       26.2129822       5.07489014
#    1959.00000       4.86981201       26.2125244       5.07583618
#    1960.00000       4.86975098       26.2122498       5.07641602
#    1961.00000       4.86972046       26.2119446       5.07693481
#    1962.00000       4.86962891       26.2116699       5.07748413
#    1963.00000       4.86956787       26.2114868       5.07797241
#    1964.00000       4.86953735       26.2112732       5.07836914
#    1965.00000       4.86950684       26.2111511       5.07888794
#    1966.00000       4.86944580       26.2109680       5.07913208
#    1967.00000       4.86947632       26.2107849       5.07943726
#    1968.00000       4.86944580       26.2106323       5.07968140
#    1969.00000       4.86941528       26.2104492       5.07992554
#    1970.00000       4.86944580       26.2102966       5.08007812
#    1971.00000       4.86938477       26.2102051       5.08029175
#    1972.00000       4.86935425       26.2100830       5.08041382
#    1973.00000       4.86938477       26.2100220       5.08050537
#    1974.00000       4.86932373       26.2099609       5.08068848
#    1975.00000       4.86944580       26.2098694       5.08078003
#    1976.00000       4.86938477       26.2098083       5.08090210
#    1977.00000       4.86938477       26.2097473       5.08093262
#    1978.00000       4.86935425       26.2097168       5.08099365
#    1979.00000       4.86935425       26.2096558       5.08105469
#    1980.00000       4.86935425       26.2096252       5.08114624
#    1981.00000       4.86935425       26.2095947       5.08114624
#    1982.00000       4.86941528       26.2095032       5.08114624
#    1983.00000       4.86941528       26.2094421       5.08120728
#    1984.00000       4.86938477       26.2094116       5.08123779
#    1985.00000       4.86941528       26.2093811       5.08123779
#    1986.00000       4.86938477       26.2093506       5.08126831
#    1987.00000       4.86941528       26.2093201       5.08129883
#    1988.00000       4.86944580       26.2093201       5.08132935
#    1989.00000       4.86944580       26.2092896       5.08135986

# %% [markdown]
# ### Copy output to bin_dir and rename

# %%
# Copy the output files to bin_files dir and rename
bin_dir = main_dir + 'bin_files/'
sh.copyfile(main_dir + 'control',bin_dir + 'control.' + exp + '.bin')
sh.copyfile(main_dir + 'scenario',bin_dir + 'scenario.' + exp + '.bin')

# %%
print exp
# %ls -tl bin_files/
# Out:
# all.pos.4ycomp
# total 965384
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 17 12:24 scenario.all.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 17 12:24 control.all.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 17 12:19 scenario.smc.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 17 12:19 control.smc.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 16 16:51 scenario.v_anom.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 16 16:51 control.v_anom.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 16 16:40 scenario.uv_anom.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 16 16:40 control.uv_anom.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 16 15:53 scenario.u_anom.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 16 15:53 control.u_anom.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 16 15:47 scenario.cld.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 16 15:47 control.cld.pos.4ycomp.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 16 15:42 scenario.4ycomp.cld.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 16 15:42 control.cld.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 16 15:41 scenario.cld.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  55296000 Mar 12 15:52 scenario.smc.neg.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 12 15:52 control.smc.neg.bin
# -rw-rw-r-- 1 nicholat nicholat 110592000 Mar 12 14:34 scenario.smc.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 12 14:34 control.smc.pos.bin
# -rw-rw-r-- 1 nicholat nicholat 110592000 Mar 11 12:26 scenario.uv_anom.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar 11 12:26 control.uv_anom.pos.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Mar  4 09:07 scenario.u_anom.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar  4 09:07 control.u_anom.pos.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Mar  4 08:58 scenario.v_anom.pos.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar  4 08:58 control.v_anom.pos.bin
# -rw-rw-r-- 1 nicholat nicholat   2211840 Mar  3 13:36 scenario.test.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar  3 13:36 control.test.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Mar  2 17:08 scenario.vwind_1msanom.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar  2 17:08 control.vwind_1msanom.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Mar  2 11:30 scenario.icealb.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Mar  2 11:30 control.icealb.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Feb 27 15:50 scenario.smc.dry.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Feb 27 15:50 control.smc.dry.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Feb 26 17:14 scenario.clim.bin
# -rw-rw-r-- 1 nicholat nicholat  13455360 Feb 26 17:14 control.clim.bin
# -rw-rw-r-- 1 nicholat nicholat   5529600 Feb 25 17:01 scenario.vanom.bin

# %% [markdown]
# ### Convert output binary files to netcdf

# %%
import output_to_nc as b2n

cube_list = b2n.write_exp(exp)
# Out:
# ./bin_files/scenario.all.pos.4ycomp.bin
# tdim = 600
# Save cube as ./ncfiles/t_surf.all.pos.4ycomp.nc
# tdim = 600
# Save cube as ./ncfiles/t_atmos.all.pos.4ycomp.nc
# tdim = 600
# Save cube as ./ncfiles/t_ocean.all.pos.4ycomp.nc
# tdim = 600
# Save cube as ./ncfiles/vapour.all.pos.4ycomp.nc
# tdim = 600
# Save cube as ./ncfiles/albedo.all.pos.4ycomp.nc

# %% [markdown]
# ### Check Output

# %%
# exp = "cld.pos.4ycomp"
# exp = "smc.neg"    trop = iris.Constraint(air_pressure = lambda p: plev_top <= p <= plev_bottom)
exp = "smc.pos.4ycomp"
# exp = "clim"
# exp = "u_anom.pos.4ycomp"
# exp = "uv_anom.pos.4ycomp"
# exp = "v_anom.pos.4ycomp"
# exp = "icealb"
# exp = "all.pos.4ycomp"
print exp
# Out:
# smc.pos.4ycomp

# %%
nc_dir = main_dir+'ncfiles/'
t_surf_clim = iris.load_cube(nc_dir + '/t_surf.clim.nc')
t_surf = iris.load_cube(nc_dir + '/t_surf.' + exp + '.nc')

gt.try_cube(t_surf_clim)
gt.try_cube(t_surf)

# take the mean of last year 
t_surf_clim_mean = t_surf_clim[:,:,-13:-1].collapsed('time',iris.analysis.MEAN)
t_surf_mean = t_surf[:,:,-13:-1].collapsed('time',iris.analysis.MEAN)
dif = t_surf_mean - t_surf_clim_mean
dif.long_name = 'Tsfc difference '+exp
qplt.pcmeshclf(dif,vmin=-0.5,vmax=0.5)
plt.savefig('./figures/tsfc_dif.'+exp+'.pdf')

#fig = pl.figure(figsize=(12,8))
#plt.subplot(2,2,1)
#qplt.pcmeshclf(t_surf_clim_mean,hold=True,cmap=mc.jetwhite(),vmax = (273.15+30), vmin = (273.15-30))
#plt.subplot(2,2,2)
#qplt.pcmeshclf(t_surf_mean,hold=True,cmap=mc.jetwhite(),vmax = (273.15+30), vmin = (273.15-30))
