# %%
# %load_ext vimception
# Out:
# The vimception extension is already loaded. To reload it, use:
#   %reload_ext vimception

# %% [markdown]
# ## Experiments with the GREB Model

# %% [markdown]
# Initial experiments
# - Wind anomaly:
#     - v_anom.pos/neg
#     - u_anom.pos/neg
#     - u_vanom.pos/neg
# - Cloud anomaly:
#     - cld.inc
#     - cld.dec
# - Soil Moisture anomaly:
#     - smc.wet
#     - smc.dry
# - SST anomaly

# %% [markdown]
# ### Creat input files and run model

# %% [markdown]
# Define the experiment name

# %%
# exp = "smc.dry"
# exp = "clim"
# exp = "v_anom.pos"
# exp = "vwind_1msanom"
exp = "test"

# %% [markdown]
# Create the input files.
#
# Copy them to main directory.

# %%
print exp
# Out:
# test

# %% [markdown]
# Run the model

# %%
# %%bash
# cat namelist
# Out:
# &NUMERICS
# time_flux = 1  ! length of flux corrections run [yrs]
# time_ctrl = 1  ! length of control run [yrs
# time_scnr = 2  ! length of scenariorun [yrs
# /
# &PHYSICS
# log_exp = 10 ! complete GREB model; 2xCO2 forcing
# /

# %% [markdown]
# #### Run GREB model

# %%
# %%bash
# # ./compile_run_greb.sh

# %%
import shutil as sh
import glob
import os

main_dir = '/home/nicholat/project/greb/'
input_dir = main_dir + 'input_files/'
orig_input_dir = main_dir + 'orig_input/'

# Copy the output files to bin_files dir and rename
bin_dir = main_dir + 'bin_files/'
sh.copyfile(main_dir + 'control',bin_dir + 'control.' + exp + '.bin')
sh.copyfile(main_dir + 'scenario',bin_dir + 'scenario.' + exp + '.bin')

# %%
ls bin_files/
# Out:
# control.clim.bin        control.vwind_1msanom.bin  scenario.vanom.bin
# control.icealb.bin      scenario.clim.bin          scenario.v_anom.pos.bin
# control.smc.dry.bin     scenario.icealb.bin        scenario.vwind_1msanom.bin
# control.test.bin        scenario.smc.dry.bin
# control.v_anom.pos.bin  scenario.test.bin

# %% [markdown]
# #### Convert output binary files to netcdf

# %%
import output_to_nc as b2n

cube_list = b2n.write_exp(exp)
# Out:
# ./bin_files/scenario.test.bin
# tdim = 24
# Save cube as ./ncfiles/t_surf.test.nc
# tdim = 24
# Save cube as ./ncfiles/t_atmos.test.nc
# tdim = 24
# Save cube as ./ncfiles/t_ocean.test.nc
# tdim = 24
# Save cube as ./ncfiles/vapour.test.nc
# tdim = 24
# Save cube as ./ncfiles/albedo.test.nc

# %% [markdown]
# #### Check output

# %%
import iris
import iris.quickplot as qplt
import matplotlib.pyplot as plt
import numpy as np
import mycmaps as mc
# %matplotlib inline

nc_dir = main_dir+'ncfiles/'
t_surf_clim = iris.load_cube(nc_dir + '/t_surf.clim.nc')
t_surf = iris.load_cube(nc_dir + '/t_surf.' + exp + '.nc')

# %%
def bounds(cube):
    cube.coord('latitude').guess_bounds()
    cube.coord('longitude').guess_bounds()
    return

# %%
bounds(t_surf_clim)
bounds(t_surf)

t_surf_clim_mean = t_surf_clim.collapsed('time',iris.analysis.MEAN)
grid_areas = iris.analysis.cartography.area_weights(t_surf_clim)
t_surf_clim_amean = t_surf_clim.collapsed(['latitude', 'longitude'],
                           iris.analysis.MEAN,
                           weights=grid_areas)

t_surf_mean = t_surf.collapsed('time',iris.analysis.MEAN)
grid_areas = iris.analysis.cartography.area_weights(t_surf)
t_surf_amean = t_surf.collapsed(['latitude', 'longitude'],
                           iris.analysis.MEAN,
                           weights=grid_areas)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d1bf30748279> in <module>()
# ----> 1 bounds(t_surf_clim)
#       2 bounds(t_surf)
#       3
#       4 t_surf_clim_mean = t_surf_clim.collapsed('time',iris.analysis.MEAN)
#       5 grid_areas = iris.analysis.cartography.area_weights(t_surf_clim)
#
# <ipython-input-12-e5ce8e22d216> in bounds(cube)
#       1 def bounds(cube):
# ----> 2     cube.coord('latitude').guess_bounds()
#       3     cube.coord('longitude').guess_bounds()
#       4     return
#
# /usr/local/lib/python2.7/dist-packages/iris/coords.pyc in guess_bounds(self, bound_position)
#    1044
#    1045         """
# -> 1046         self.bounds = self._guess_bounds(bound_position)
#    1047
#    1048     def intersect(self, other, return_indices=False):
#
# /usr/local/lib/python2.7/dist-packages/iris/coords.pyc in _guess_bounds(self, bound_position)
#     999
#    1000         if self.bounds is not None:
# -> 1001             raise ValueError('Coord already has bounds. Remove the bounds '
#    1002                              'before guessing new ones.')
#    1003
#
# ValueError: Coord already has bounds. Remove the bounds before guessing new ones.

# %%
fig = plt.figure(figsize=(12,8))
plt.subplot(1,2,1)
qplt.pcmeshclf(t_surf_clim_mean,hold=True,cmap=mc.jetwhite(),vmax = (273.15+30), vmin = (273.15-30))
plt.subplot(1,2,2)
qplt.pcmeshclf(t_surf_mean,hold=True,cmap=mc.jetwhite(),vmax = (273.15+30), vmin = (273.15-30))

# %%
qplt.pcmeshclf(t_surf_mean-t_surf_clim_mean) #,cmap=mc.jetwhite(),vmin=-1,vmax=1)
plt.title('Tsurf response, vwind - 1ms')
# plt.savefig('./figures/t_surf.'+exp+'.response.pdf')
